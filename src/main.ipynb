# %%
import numpy as np
import matplotlib.pyplot as plt

# General cuspy density profile
def cuspy_density(r, rho0, rs, gamma):
    return rho0 * (r/rs)**(-gamma)

# Parameters
rho0 = 1.0  # Normalization constant
rs = 10.0   # Scale radius
gamma = 0.1 # Slope of the cusp (e.g., 1 for singular isothermal sphere)
r = np.logspace(-2, 2, 1000)  # Radial range

# Calculate density
density = cuspy_density(r, rho0, rs, gamma)

# Plot
plt.loglog(r, density, label=f'Cuspy Profile (γ = {gamma})')
plt.xlabel('Radius (r)')
plt.ylabel('Density (ρ)')
plt.title('General Cuspy Density Profile')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 24
#      22 plt.legend()
#      23 plt.grid(True)
# ---> 24 plt.show()
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/backend_bases.py:2342, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336     renderer = _get_renderer(
#    2337         self.figure,
#    2338         functools.partial(
#    2339             print_method, orientation=orientation)
#    2340     )
#    2341     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342         self.figure.draw(renderer)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/figure.py:3175, in Figure.draw(self, renderer)
#    3172         # ValueError can occur when resizing a window.
#    3174 self.patch.draw(renderer)
# -> 3175 mimage._draw_list_compositing_images(
#    3176     renderer, self, artists, self.suppressComposite)
#    3178 for sfig in self.subfigs:
#    3179     sfig.draw(renderer)
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/axes/_base.py:3064, in _AxesBase.draw(self, renderer)
#    3061 if artists_rasterized:
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3064 mimage._draw_list_compositing_images(
#    3065     renderer, self, artists, self.figure.suppressComposite)
#    3067 renderer.close_group('axes')
#    3068 self.stale = False
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/axis.py:1380, in Axis.draw(self, renderer, *args, **kwargs)
#    1377 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1379 for tick in ticks_to_draw:
# -> 1380     tick.draw(renderer)
#    1382 # Shift label away from axes to avoid overlapping ticklabels.
#    1383 self._update_label_position(renderer)
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/axis.py:301, in Tick.draw(self, renderer)
#     298 renderer.open_group(self.__name__, gid=self.get_gid())
#     299 for artist in [self.gridline, self.tick1line, self.tick2line,
#     300                self.label1, self.label2]:
# --> 301     artist.draw(renderer)
#     302 renderer.close_group(self.__name__)
#     303 self.stale = False
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/lines.py:836, in Line2D.draw(self, renderer)
#     833         tpath, affine = (self._get_transformed_path()
#     834                          .get_transformed_points_and_affine())
#     835 else:
# --> 836     tpath, affine = (self._get_transformed_path()
#     837                      .get_transformed_points_and_affine())
#     839 if len(tpath.vertices):
#     840     # subsample the markers if markevery is not None
#     841     markevery = self.get_markevery()
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/transforms.py:2780, in TransformedPath.get_transformed_points_and_affine(self)
#    2772 def get_transformed_points_and_affine(self):
#    2773     """
#    2774     Return a copy of the child path, with the non-affine part of
#    2775     the transform already applied, along with the affine part of
#    (...)
#    2778     be performed.
#    2779     """
# -> 2780     self._revalidate()
#    2781     return self._transformed_points, self.get_affine()
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/transforms.py:2765, in TransformedPath._revalidate(self)
#    2759 def _revalidate(self):
#    2760     # only recompute if the invalidation includes the non_affine part of
#    2761     # the transform
#    2762     if (self._invalid & self.INVALID_NON_AFFINE == self.INVALID_NON_AFFINE
#    2763             or self._transformed_path is None):
#    2764         self._transformed_path = \
# -> 2765             self._transform.transform_path_non_affine(self._path)
#    2766         self._transformed_points = \
#    2767             Path._fast_from_codes_and_verts(
#    2768                 self._transform.transform_non_affine(self._path.vertices),
#    2769                 None, self._path)
#    2770     self._invalid = 0
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/transforms.py:1623, in Transform.transform_path_non_affine(self, path)
#    1615 def transform_path_non_affine(self, path):
#    1616     """
#    1617     Apply the non-affine part of this transform to `.Path` *path*,
#    1618     returning a new `.Path`.
#    (...)
#    1621     ``transform_path_affine(transform_path_non_affine(values))``.
#    1622     """
# -> 1623     x = self.transform_non_affine(path.vertices)
#    1624     return Path._fast_from_codes_and_verts(x, path.codes, path)
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/transforms.py:2241, in BlendedGenericTransform.transform_non_affine(self, points)
#    2238     return x.transform_non_affine(points)
#    2240 if x.input_dims == 2:
# -> 2241     x_points = x.transform_non_affine(points)[:, 0:1]
#    2242 else:
#    2243     x_points = x.transform_non_affine(points[:, 0])
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/transforms.py:2430, in CompositeGenericTransform.transform_non_affine(self, points)
#    2428     return points
#    2429 elif not self._a.is_affine and self._b.is_affine:
# -> 2430     return self._a.transform_non_affine(points)
#    2431 else:
#    2432     return self._b.transform_non_affine(self._a.transform(points))
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/matplotlib/transforms.py:2256, in BlendedGenericTransform.transform_non_affine(self, points)
#    2254     return np.ma.concatenate((x_points, y_points), 1)
#    2255 else:
# -> 2256     return np.concatenate((x_points, y_points), 1)
#
# File ~/miniconda3/envs/requqira/lib/python3.9/site-packages/numpy/core/multiarray.py:153, in concatenate(arrays, axis, out, dtype, casting)
#      87     """
#      88     empty_like(prototype, dtype=None, order='K', subok=True, shape=None)
#      89
#    (...)
#     148
#     149     """
#     150     return (prototype,)
# --> 153 @array_function_from_c_func_and_dispatcher(_multiarray_umath.concatenate)
#     154 def concatenate(arrays, axis=None, out=None, *, dtype=None, casting=None):
#     155     """
#     156     concatenate((a1, a2, ...), axis=0, out=None, dtype=None, casting="same_kind")
#     157
#    (...)
#     245
#     246     """
#     247     if out is not None:
#     248         # optimize for the typical case where only arrays is provided
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt

# NFW density profile function
def nfw_density(r, rho0, rs):
    return rho0 / ((r/rs) * (1 + r/rs)**2)

# Parameters
rho0 = 1.0  # Characteristic density
rs = 10.0   # Scale radius
r = np.logspace(-2, 2, 1000)  # Radial range

# Calculate density
density = nfw_density(r, rho0, rs)

# Plot
plt.loglog(r, density, label='NFW Profile')
plt.xlabel('Radius (r)')
plt.ylabel('Density (ρ)')
plt.title('NFW Density Profile')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Process

# %%
import pandas as pd
data_path = "../data/merge_L0025N0752.csv"

data = pd.read_csv(data_path)
data
# Out:
#          Unnamed: 0         GroupID  SnapNum      Redshift  RandomNumber  \
# 0                 0               0        0  2.000002e+01      0.258937
# 1                 1       100000000        0  2.000002e+01      0.375942
# 2                 2       200000000        0  2.000002e+01      0.851697
# 3                 3       300000000        0  2.000002e+01      0.191182
# 4                 4       400000000        0  2.000002e+01      0.020750
# ...             ...             ...      ...           ...           ...
# 8058640     8058640  28051100000511       28  2.220446e-16      0.491228
# 8058641     8058641  28051100000512       28  2.220446e-16      0.052242
# 8058642     8058642  28051100000513       28  2.220446e-16      0.291164
# 8058643     8058643  28051100000514       28  2.220446e-16      0.760296
# 8058644     8058644  28051100000515       28  2.220446e-16      0.130354
#
#            GroupMass  GroupCentreOfPotential_x  GroupCentreOfPotential_y  \
# 0        494628960.0                 17.610989                  5.887995
# 1        473060864.0                 13.875363                 24.799456
# 2        444303328.0                  5.131043                  4.421177
# 3        340776352.0                 13.289849                  0.188732
# 4        266006864.0                  6.091486                 10.210695
# ...              ...                       ...                       ...
# 8058640   46011996.0                  0.756148                 22.802591
# 8058641   46011996.0                 23.854416                 21.874290
# 8058642   46011996.0                 23.816847                 21.964525
# 8058643   46011996.0                 23.175740                 22.572882
# 8058644   46011996.0                 23.022680                 22.729515
#
#          GroupCentreOfPotential_z  NumOfSubhalos  ...  Vmax  VmaxRadius  Mass  \
# 0                       21.443748              2  ...   NaN         NaN   NaN
# 1                       22.481564              1  ...   NaN         NaN   NaN
# 2                       15.773108              2  ...   NaN         NaN   NaN
# 3                       22.353159              3  ...   NaN         NaN   NaN
# 4                       24.551619              1  ...   NaN         NaN   NaN
# ...                           ...            ...  ...   ...         ...   ...
# 8058640                 19.687693              0  ...   NaN         NaN   NaN
# 8058641                 18.571035              1  ...   NaN         NaN   NaN
# 8058642                 18.662937              0  ...   NaN         NaN   NaN
# 8058643                 17.818602              0  ...   NaN         NaN   NaN
# 8058644                 17.798288              1  ...   NaN         NaN   NaN
#
#          MassType_DM  HalfMassProjRad_DM  HalfMassRad_DM  nodeIndex  \
# 0                NaN                 NaN             NaN        NaN
# 1                NaN                 NaN             NaN        NaN
# 2                NaN                 NaN             NaN        NaN
# 3                NaN                 NaN             NaN        NaN
# 4                NaN                 NaN             NaN        NaN
# ...              ...                 ...             ...        ...
# 8058640          NaN                 NaN             NaN        NaN
# 8058641          NaN                 NaN             NaN        NaN
# 8058642          NaN                 NaN             NaN        NaN
# 8058643          NaN                 NaN             NaN        NaN
# 8058644          NaN                 NaN             NaN        NaN
#
#          PosInFile  FileNum  Image_ID
# 0              NaN      NaN       NaN
# 1              NaN      NaN       NaN
# 2              NaN      NaN       NaN
# 3              NaN      NaN       NaN
# 4              NaN      NaN       NaN
# ...            ...      ...       ...
# 8058640        NaN      NaN       NaN
# 8058641        NaN      NaN       NaN
# 8058642        NaN      NaN       NaN
# 8058643        NaN      NaN       NaN
# 8058644        NaN      NaN       NaN
#
# [8058645 rows x 52 columns]

# %%
from data_processing import DataProcessor,  DMDataset
import os

data_path = "../../data/merge_L0100N1504.feather"
print(data_path.endswith(".feather"))  # Should be True
print(os.path.exists(data_path))       # Should be True

dp = DataProcessor(data_path=data_path)
dp.load_data()
# Out:
# True
# True
# Data loaded successfully.

# %%
from data_processing import DataProcessor,  DMDataset

def __main__():
    # Load Data
    data_path = "../../data/merge_L0100N1504.feather"
    dp = DataProcessor(data_path=data_path)
    dp.load_data()
    dp.missing_values()
    dp.basic_statistics()
    dp.data_distribution()
    #dp.correlation_heatmap()
    train_data, val_data = dp.preprocess_data(scaler_type="robust", coverage=0.85)

__main__()
# Out:
# Data loaded successfully.
# Missing values handled.
# Data split into training and validation sets.
# Data scaled using robust scaler.
# Data have been successfully normalized.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      10     #dp.data_distribution()
#      11     #dp.correlation_heatmap()
#      12     train_data, val_data = dp.preprocess_data(scaler_type="robust", coverage=0.85)
# ---> 14 __main__()
#
# Cell In[1], line 12, in __main__()
#       9 dp.basic_statistics()
#      10 #dp.data_distribution()
#      11 #dp.correlation_heatmap()
# ---> 12 train_data, val_data = dp.preprocess_data(scaler_type="robust", coverage=0.85)
#
# File ~/dmmapper/model/src/data_processing.py:423, in DataProcessor.preprocess_data(self, scaler_type, coverage)
#     421 self.normalize_data()
#     422 self.integrate_data()
# --> 423 self.final_clip(coverage)
#     424 return self.train_data_integrate, self.val_data_integrate
#
# File ~/dmmapper/model/src/data_processing.py:394, in DataProcessor.final_clip(self, coverage_percentage)
#     392 # Calculate the z-score threshold based on the coverage percentage
#     393 alpha = (100 - coverage_percentage) / 100
# --> 394 z_threshold = abs(np.percentile(np.random.Generator(0, 1, 1000000), [alpha * 50, 100 - alpha * 50]))[1]
#     396 # Calculate mean and standard
#     397 for column in self.train.columns:
#
# File numpy/random/_generator.pyx:196, in numpy.random._generator.Generator.__init__()
#
# TypeError: __init__() takes exactly 1 positional argument (3 given)

# %% [markdown]
# ## Process Data

# %% [markdown]
# ##  Discover Hyper Parameter

# %% [markdown]
# ## Train Model

# %% [markdown]
# ## Model Visualization

# %% [markdown]
# # Compile

# %%
from data_processing import DataProcessor,  DMDataset
from model_train import ModelTrainer
from model_hyperparameter_optimizer import RNNHyperParameterOptimizer
from rnn_model import RNNDMHaloMapper, LSTMDMHaloMapper, GRUDMHaloMapper
from redshift_analyzer import RedshiftAnalyzer
from model_visualization import ModelVisualizer
import torch as tc
import torch.optim as tco
import torch.utils.data as tcud
import torch.nn as tcn
from sklearn.model_selection import train_test_split


class DMHaloMapper:
    def __init__(self, data=None, device=None, model=None):
        self.device = device if device is not None else tc.device('cuda' if tc.cuda.is_available() else 'cpu')
        self.dp = DataProcessor(data_path=data)
        self.mt = ModelTrainer()
        self.dm = DMDataset()
        self.hp = None
        self.mv = ModelVisualizer()
        self.rnn = RNNDMHaloMapper()
        self.lstm = LSTMDMHaloMapper()
        self.gru = GRUDMHaloMapper()
        self.train_data = None
        self.val_data = None
        self.X = None
        self.y = None
        self.features = None
        self.targets = None
        self.redshift_values = None
        self.unique_redshifts = None
        self.best_hyperparameter = None
        self.model=model

    def data_process(self):
        self.dp.load_data()
        self.dp.missing_values()
        self.dp.basic_statistics()
        self.dp.data_distribution()
        self.dp.correlation_heatmap()
        self.train_data, self.val_data = self.dp.preprocess_data(scaler_type="robust", coverage=0.85)
        self.dp.preprocessed_distribution()
    
    def data_to_tensor(self):
        features = [
            'Redshift',
            'NumOfSubhalos',
            'Velocity_x',
            'Velocity_y',
            'Velocity_z',
            'MassType_DM',
            'CentreOfPotential_x',
            'CentreOfPotential_y',
            'CentreOfPotential_z',
            'GroupCentreOfPotential_x',
            'GroupCentreOfPotential_y',
            'GroupCentreOfPotential_z',
            'Vmax',
            'VmaxRadius',
            'Group_R_Crit200'
        ]
        
        targets = ['Group_M_Crit200']
        
        self.X = self.train_data[features]
        self.y = self.train_data[targets].values.reshape(-1, 1)
        
        self.features, self.targets = self.dm(self.X, self.y)
    
    def process_redshift(self):
        self.ra = RedshiftAnalyzer(self.train_data, self.features)
        self.redshift_values, self.unique_redshifts = self.ra.process_redshift_data()
    
    def discover_hyperparameter(self):
        print(f"Starting discover_hyperparameter for {len(self.models_to_optimize)} models...")
        self.models_to_optimize = [self.rnn, self.lstm, self.gru]
        
        optimization_results = []
        
        self.hp = RNNHyperParameterOptimizer(
            X=self.X,
            y=self.y,
            base_model_class=RNNDMHaloMapper,  # You can change this to LSTMDMHaloMapper or GRUDMHaloMapper
            device=self.device,
            num_features=self.X.shape[1],
            pop_size=20,
            maxiter=100,
            cross_val_folds=13
        )
        
        # Run optimization
        optimization_result = self.hp.optimize()
        
        if optimization_result:
            self.best_hyperparameters = optimization_result['best_params']
            print("Best hyperparameters found:")
            for param, value in self.best_hyperparameters.items():
                print(f"{param}: {value}")
        else:
            print("Hyperparameter optimization failed. Using default hyperparameters.")
            self.best_hyperparameters = {
                'hidden_size': 256,
                'num_layers': 2,
                'dropout_rate': 0.2,
                'learning_rate': 0.001,
                'batch_size': 64,
                'weight_decay': 0.0001,
                'num_epochs': 10
            }
        
    def train_rnn_model(self):
        """
        Train the RNN, LSTM, and GRU models using the best hyperparameters.
        """
        if not self.best_hyperparameters:
            print("No hyperparameters found. Running discover_hyperparameter first.")
            self.discover_hyperparameter()

        input_size = self.X.shape[1]
        output_size = 1

        # Define models with the best hyperparameters
        models = {
            'RNN': RNNDMHaloMapper(
                input_size=input_size,
                hidden_size=self.best_hyperparameters['hidden_size'],
                output_size=output_size,
                num_layers=self.best_hyperparameters['num_layers'],
                dropout_rate=self.best_hyperparameters['dropout_rate'],
                learning_rate=self.best_hyperparameters['learning_rate'],
                batch_size=self.best_hyperparameters['batch_size'],
                weight_decay=self.best_hyperparameters['weight_decay'],
                num_epochs=self.best_hyperparameters['num_epochs']
            ),
            'LSTM': LSTMDMHaloMapper(
                input_size=input_size,
                hidden_size=self.best_hyperparameters['hidden_size'],
                output_size=output_size,
                num_layers=self.best_hyperparameters['num_layers'],
                dropout_rate=self.best_hyperparameters['dropout_rate'],
                learning_rate=self.best_hyperparameters['learning_rate'],
                batch_size=self.best_hyperparameters['batch_size'],
                weight_decay=self.best_hyperparameters['weight_decay'],
                num_epochs=self.best_hyperparameters['num_epochs']
            ),
            'GRU': GRUDMHaloMapper(
                input_size=input_size,
                hidden_size=self.best_hyperparameters['hidden_size'],
                output_size=output_size,
                num_layers=self.best_hyperparameters['num_layers'],
                dropout_rate=self.best_hyperparameters['dropout_rate'],
                learning_rate=self.best_hyperparameters['learning_rate'],
                batch_size=self.best_hyperparameters['batch_size'],
                weight_decay=self.best_hyperparameters['weight_decay'],
                num_epochs=self.best_hyperparameters['num_epochs']
            )
        }

        X_train, X_val, y_train, y_val = train_test_split(self.X, self.y, test_size=0.25, random_state=42)

        self.X_val = X_val
        self.y_val = y_val
        
        train_dataset = DMDataset(X_train, y_train)
        val_dataset = DMDataset(X_val, y_val)

        train_loader = DMDataset.data_loader(train_dataset, batch_size=self.best_hyperparameters['batch_size'])
        val_loader = DMDataset.data_loader(val_dataset, batch_size=self.best_hyperparameters['batch_size'])
        '''train_loader = tcud.DataLoader(
            train_dataset,
            batch_size=self.best_hyperparameters['batch_size'],
            shuffle=True,
            num_workers=0,
            pin_memory=True if self.device.type == 'cuda' else False
        )

        val_loader = tcud.DataLoader(
            val_dataset,
            batch_size=self.best_hyperparameters['batch_size'],
            shuffle=False,
            num_workers=0,
            pin_memory=True if self.device.type == 'cuda' else False
        )'''

        model_results = {}

        for name, model in models.items():
            print(f"\nTraining {name} model with optimized hyperparameters...")
            optimizer = tco.Adam(model.parameters(), lr=self.best_hyperparameters['learning_rate'], weight_decay=self.best_hyperparameters['weight_decay'])
            criterion = tcn.MSELoss()

            history, model_dir = self.mt.train_model(
                model=model,
                train_loader=train_loader,
                val_loader=val_loader,
                criterion=criterion,
                optimizer=optimizer,
                num_epochs=self.best_hyperparameters['num_epochs'],
                device=self.device,
                model_name=name,
                save_dir='./best_model'
            )

            model_results[name] = {
                'history': history,
                'model_dir': model_dir
            }

        return model_results
    
    def process_model(self):
        """
        Process the validation dataset, make predictions, and store results for visualization.
        """
        if not hasattr(self, 'models'):
            print("No trained models found. Run train_rnn_model first.")
            return

        # Load validation data
        X_val_tensor = tc.tensor(self.X_val.values, dtype=tc.float32)
        self.y_val = self.y[self.X_val.index]

        # Make predictions on the validation set
        self.val_predictions = {}
        for name, model in self.models.items():
            model.eval()
            with tc.no_grad():
                outputs = model(X_val_tensor.to(self.device))
                if isinstance(outputs, tuple):
                    outputs = outputs[0]
                self.val_predictions[name] = outputs.cpu().numpy()

        print("Validation dataset processed and predictions stored.")
    
    def model_visualization(self):
        """
        Visualize the model's predictions, including dark matter distribution, triaxial model, and redshift evolution.
        """
        if not hasattr(self, 'val_predictions'):
            print("No validation predictions found. Run process_model first.")
            return

        # Extract spatial coordinates for visualization
        X_val_tensor = tc.tensor(self.X_val.values, dtype=tc.float32)
        column_indices = [self.X.columns.get_loc(f) for f in 
            [
                'GroupCentreOfPotential_x',
                'GroupCentreOfPotential_y',
                'GroupCentreOfPotential_z'
            ]
        ]
        spatial_coords = X_val_tensor[:, column_indices].numpy()

        # Initialize ModelVisualizer
        self.mv = ModelVisualizer(
            predictions=self.val_predictions['RNN'],  # Use RNN predictions as an example
            true_values=self.y_val,
            spatial_coords=spatial_coords,
            redshifts=self.redshift_values[self.X_val.index],
            save_dir='./visualizations'
        )

        # Generate and save visualizations
        self.mv.visualize_dm_distribution(a=1.0, b=0.8, c=0.6)

    
    def run_process(self):
        try:
            self.data_process()
            self.data_to_tensor()
            self.process_redshift()
            self.discover_hyperparameter()
            self.train_rnn_model()
            self.model_visualization()
            self.process_model()
        except Exception as e:
            print(f"An error occurred: {e}")
    
def __main__():
    dmhalo_mapper = DMHaloMapper()
    dmhalo_mapper.run_process(model='GRU')

if __name__ == "__main__":
    __main__()

# %%
import pandas as pd
import numpy as np
from astropy.cosmology import FlatLambdaCDM

df = pd.read_feather("../data/merge_L0100N1504.feather")

# %%
def add_cosmological_time(data):
    """
    Add lookback time and age of the universe (in Gyr) based on the Redshift column.
    """
    try:
        if data is None:
            return
            
        if "Redshift" not in data.columns:
            return
            
        # Filter invalid redshift
        invalid_redshift = data[data["Redshift"] < 0]
        if not invalid_redshift.empty:
            print(f"Invalid redshift values found: {invalid_redshift['Redshift'].values}")
            data = data[data["Redshift"] >= 0]   
                     
        # Define cosmolical parameters (Planck 2018)
        cosmo = FlatLambdaCDM(name='Planck18', H0=67.66, Om0=0.30966, Tcmb0=2.7255, Neff=3.046, m_nu=[0.  , 0.  , 0.06], Ob0=0.04897)
            
            # Initialize columns
        data["LookbackTime"] = np.nan
        data["UniverseAge"] = np.nan

            # Only compute for valid redshift (>= 0)
        valid_idx = data[data["Redshift"] >= 0].index
        data.loc[valid_idx, "LookbackTime"] = cosmo.lookback_time(data.loc[valid_idx, "Redshift"]).value
        data.loc[valid_idx, "UniverseAge"] = cosmo.age(data.loc[valid_idx, "Redshift"]).value
            
        '''# Add columns
            self.data["LookbackTime"] = cosmo.lookback_time(self.data["Redshift"]).value
            self.data["UniverseAge"] = cosmo.age(self.data["Redshift"]).value
            '''
        
        return df
    except Exception as e:
        print(f"Error in add_cosmological_time: {e}")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df = add_cosmological_time(df)
df

# %%
import pandas as pd

data1 = pd.read_feather("../data/merge_L0025N0376_with_cosmological_time.feather")
data2 = pd.read_feather("../data/merge_L0025N0752_with_cosmological_time.feather")
data3 = pd.read_feather("../data/merge_L0100N1504_with_cosmological_time.feather")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236622 entries, 0 to 1236621
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   GroupID                   1084535 non-null  float64
#  1   SnapNum                   1084535 non-null  float64
#  2   Redshift                  1084535 non-null  float64
#  3   RandomNumber              1084535 non-null  float64
#  4   GroupMass                 1084535 non-null  float64
#  5   GroupCentreOfPotential_x  1084535 non-null  float64
#  6   GroupCentreOfPotential_y  1084535 non-null  float64
#  7   GroupCentreOfPotential_z  1084535 non-null  float64
#  8   NumOfSubhalos             1084535 non-null  float64
#  9   Group_M_Crit200           1084535 non-null  float64
#  10  Group_R_Crit200           1084535 non-null  float64
#  11  Group_M_Mean200           1084535 non-null  float64
#  12  Group_R_Mean200           1084535 non-null  float64
#  13  Group_M_TopHat200         1084535 non-null  float64
#  14  Group_R_TopHat200         1084535 non-null  float64
#  15  Group_M_Crit500           1084535 non-null  float64
#  16  Group_R_Crit500           1084535 non-null  float64
#  17  Group_M_Mean500           1084535 non-null  float64
#  18  Group_R_Mean500           1084535 non-null  float64
#  19  Group_M_Crit2500          1084535 non-null  float64
#  20  Group_R_Crit2500          1084535 non-null  float64
#  21  Group_R_Mean2500          1084535 non-null  float64
#  22  Group_M_Mean2500          1084535 non-null  float64
#  23  GalaxyID                  1236622 non-null  int64
#  24  DescendantID              1236622 non-null  int64
#  25  LastProgID                1236622 non-null  int64
#  26  TopLeafID                 1236622 non-null  int64
#  27  GroupNumber               1236622 non-null  int64
#  28  SubGroupNumber            1236622 non-null  int64
#  29  CentreOfMass_x            1236622 non-null  float64
#  30  CentreOfMass_y            1236622 non-null  float64
#  31  CentreOfMass_z            1236622 non-null  float64
#  32  CentreOfPotential_x       1236622 non-null  float64
#  33  CentreOfPotential_y       1236622 non-null  float64
#  34  CentreOfPotential_z       1236622 non-null  float64
#  35  Velocity_x                1236622 non-null  float64
#  36  Velocity_y                1236622 non-null  float64
#  37  Velocity_z                1236622 non-null  float64
#  38  KineticEnergy             1236622 non-null  float64
#  39  MechanicalEnergy          1236622 non-null  float64
#  40  TotalEnergy               1236622 non-null  float64
#  41  Vmax                      1236622 non-null  float64
#  42  VmaxRadius                1236622 non-null  float64
#  43  Mass                      1236622 non-null  float64
#  44  MassType_DM               1236622 non-null  float64
#  45  HalfMassProjRad_DM        1236622 non-null  float64
#  46  HalfMassRad_DM            1236622 non-null  float64
#  47  nodeIndex                 1236622 non-null  int64
#  48  PosInFile                 1236622 non-null  int64
#  49  FileNum                   1236622 non-null  int64
#  50  Image_ID                  1236622 non-null  int64
#  51  LookbackTime              1084535 non-null  float64
#  52  UniverseAge               1084535 non-null  float64
# dtypes: float64(43), int64(10)
# memory usage: 500.0 MB

# %%
for col in data1.columns:
    print(f"{col}: {data1[col].dtype}")
# Out:
# GroupID: float64
# SnapNum: float64
# Redshift: float64
# RandomNumber: float64
# GroupMass: float64
# GroupCentreOfPotential_x: float64
# GroupCentreOfPotential_y: float64
# GroupCentreOfPotential_z: float64
# NumOfSubhalos: float64
# Group_M_Crit200: float64
# Group_R_Crit200: float64
# Group_M_Mean200: float64
# Group_R_Mean200: float64
# Group_M_TopHat200: float64
# Group_R_TopHat200: float64
# Group_M_Crit500: float64
# Group_R_Crit500: float64
# Group_M_Mean500: float64
# Group_R_Mean500: float64
# Group_M_Crit2500: float64
# Group_R_Crit2500: float64
# Group_R_Mean2500: float64
# Group_M_Mean2500: float64
# GalaxyID: int64
# DescendantID: int64
# LastProgID: int64
# TopLeafID: int64
# GroupNumber: int64
# SubGroupNumber: int64
# CentreOfMass_x: float64
# CentreOfMass_y: float64
# CentreOfMass_z: float64
# CentreOfPotential_x: float64
# CentreOfPotential_y: float64
# CentreOfPotential_z: float64
# Velocity_x: float64
# Velocity_y: float64
# Velocity_z: float64
# KineticEnergy: float64
# MechanicalEnergy: float64
# TotalEnergy: float64
# Vmax: float64
# VmaxRadius: float64
# Mass: float64
# MassType_DM: float64
# HalfMassProjRad_DM: float64
# HalfMassRad_DM: float64
# nodeIndex: int64
# PosInFile: int64
# FileNum: int64
# Image_ID: int64
# LookbackTime: float64
# UniverseAge: float64

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9788574 entries, 0 to 9788573
# Data columns (total 53 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   GroupID                   int64
#  1   SnapNum                   int64
#  2   Redshift                  float64
#  3   RandomNumber              float64
#  4   GroupMass                 float64
#  5   GroupCentreOfPotential_x  float64
#  6   GroupCentreOfPotential_y  float64
#  7   GroupCentreOfPotential_z  float64
#  8   NumOfSubhalos             int64
#  9   Group_M_Crit200           float64
#  10  Group_R_Crit200           float64
#  11  Group_M_Mean200           float64
#  12  Group_R_Mean200           float64
#  13  Group_M_TopHat200         float64
#  14  Group_R_TopHat200         float64
#  15  Group_M_Crit500           float64
#  16  Group_R_Crit500           float64
#  17  Group_M_Mean500           float64
#  18  Group_R_Mean500           float64
#  19  Group_M_Crit2500          float64
#  20  Group_R_Crit2500          float64
#  21  Group_R_Mean2500          float64
#  22  Group_M_Mean2500          float64
#  23  GalaxyID                  float64
#  24  DescendantID              float64
#  25  LastProgID                float64
#  26  TopLeafID                 float64
#  27  GroupNumber               float64
#  28  SubGroupNumber            float64
#  29  CentreOfMass_x            float64
#  30  CentreOfMass_y            float64
#  31  CentreOfMass_z            float64
#  32  CentreOfPotential_x       float64
#  33  CentreOfPotential_y       float64
#  34  CentreOfPotential_z       float64
#  35  Velocity_x                float64
#  36  Velocity_y                float64
#  37  Velocity_z                float64
#  38  KineticEnergy             float64
#  39  MechanicalEnergy          float64
#  40  TotalEnergy               float64
#  41  Vmax                      float64
#  42  VmaxRadius                float64
#  43  Mass                      float64
#  44  MassType_DM               float64
#  45  HalfMassProjRad_DM        float64
#  46  HalfMassRad_DM            float64
#  47  nodeIndex                 float64
#  48  PosInFile                 float64
#  49  FileNum                   float64
#  50  Image_ID                  float64
#  51  LookbackTime              float64
#  52  UniverseAge               float64
# dtypes: float64(50), int64(3)
# memory usage: 3.9 GB

# %%
for col in data2.columns:
    print(f"{col}: {data2[col].dtype}")
# Out:
# GroupID: int64
# SnapNum: int64
# Redshift: float64
# RandomNumber: float64
# GroupMass: float64
# GroupCentreOfPotential_x: float64
# GroupCentreOfPotential_y: float64
# GroupCentreOfPotential_z: float64
# NumOfSubhalos: int64
# Group_M_Crit200: float64
# Group_R_Crit200: float64
# Group_M_Mean200: float64
# Group_R_Mean200: float64
# Group_M_TopHat200: float64
# Group_R_TopHat200: float64
# Group_M_Crit500: float64
# Group_R_Crit500: float64
# Group_M_Mean500: float64
# Group_R_Mean500: float64
# Group_M_Crit2500: float64
# Group_R_Crit2500: float64
# Group_R_Mean2500: float64
# Group_M_Mean2500: float64
# GalaxyID: float64
# DescendantID: float64
# LastProgID: float64
# TopLeafID: float64
# GroupNumber: float64
# SubGroupNumber: float64
# CentreOfMass_x: float64
# CentreOfMass_y: float64
# CentreOfMass_z: float64
# CentreOfPotential_x: float64
# CentreOfPotential_y: float64
# CentreOfPotential_z: float64
# Velocity_x: float64
# Velocity_y: float64
# Velocity_z: float64
# KineticEnergy: float64
# MechanicalEnergy: float64
# TotalEnergy: float64
# Vmax: float64
# VmaxRadius: float64
# Mass: float64
# MassType_DM: float64
# HalfMassProjRad_DM: float64
# HalfMassRad_DM: float64
# nodeIndex: float64
# PosInFile: float64
# FileNum: float64
# Image_ID: float64
# LookbackTime: float64
# UniverseAge: float64

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22109109 entries, 0 to 22109108
# Data columns (total 53 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   GroupID                   int64
#  1   SnapNum                   float64
#  2   Redshift                  float64
#  3   RandomNumber              float64
#  4   GroupMass                 float64
#  5   GroupCentreOfPotential_x  float64
#  6   GroupCentreOfPotential_y  float64
#  7   GroupCentreOfPotential_z  float64
#  8   NumOfSubhalos             float64
#  9   Group_M_Crit200           float64
#  10  Group_R_Crit200           float64
#  11  Group_M_Mean200           float64
#  12  Group_R_Mean200           float64
#  13  Group_M_TopHat200         float64
#  14  Group_R_TopHat200         float64
#  15  Group_M_Crit500           float64
#  16  Group_R_Crit500           float64
#  17  Group_M_Mean500           float64
#  18  Group_R_Mean500           float64
#  19  Group_M_Crit2500          float64
#  20  Group_R_Crit2500          float64
#  21  Group_R_Mean2500          float64
#  22  Group_M_Mean2500          float64
#  23  GalaxyID                  int64
#  24  DescendantID              float64
#  25  LastProgID                float64
#  26  TopLeafID                 float64
#  27  GroupNumber               float64
#  28  SubGroupNumber            float64
#  29  CentreOfMass_x            float64
#  30  CentreOfMass_y            float64
#  31  CentreOfMass_z            float64
#  32  CentreOfPotential_x       float64
#  33  CentreOfPotential_y       float64
#  34  CentreOfPotential_z       float64
#  35  Velocity_x                float64
#  36  Velocity_y                float64
#  37  Velocity_z                float64
#  38  KineticEnergy             float64
#  39  MechanicalEnergy          float64
#  40  TotalEnergy               float64
#  41  Vmax                      float64
#  42  VmaxRadius                float64
#  43  Mass                      float64
#  44  MassType_DM               float64
#  45  HalfMassProjRad_DM        float64
#  46  HalfMassRad_DM            float64
#  47  nodeIndex                 float64
#  48  PosInFile                 float64
#  49  FileNum                   float64
#  50  Image_ID                  float64
#  51  LookbackTime              float64
#  52  UniverseAge               float64
# dtypes: float64(51), int64(2)
# memory usage: 8.7 GB

# %%
for col in data3.columns:
    print(f"{col}: {data3[col].dtype}")
# Out:
# GroupID: int64
# SnapNum: float64
# Redshift: float64
# RandomNumber: float64
# GroupMass: float64
# GroupCentreOfPotential_x: float64
# GroupCentreOfPotential_y: float64
# GroupCentreOfPotential_z: float64
# NumOfSubhalos: float64
# Group_M_Crit200: float64
# Group_R_Crit200: float64
# Group_M_Mean200: float64
# Group_R_Mean200: float64
# Group_M_TopHat200: float64
# Group_R_TopHat200: float64
# Group_M_Crit500: float64
# Group_R_Crit500: float64
# Group_M_Mean500: float64
# Group_R_Mean500: float64
# Group_M_Crit2500: float64
# Group_R_Crit2500: float64
# Group_R_Mean2500: float64
# Group_M_Mean2500: float64
# GalaxyID: int64
# DescendantID: float64
# LastProgID: float64
# TopLeafID: float64
# GroupNumber: float64
# SubGroupNumber: float64
# CentreOfMass_x: float64
# CentreOfMass_y: float64
# CentreOfMass_z: float64
# CentreOfPotential_x: float64
# CentreOfPotential_y: float64
# CentreOfPotential_z: float64
# Velocity_x: float64
# Velocity_y: float64
# Velocity_z: float64
# KineticEnergy: float64
# MechanicalEnergy: float64
# TotalEnergy: float64
# Vmax: float64
# VmaxRadius: float64
# Mass: float64
# MassType_DM: float64
# HalfMassProjRad_DM: float64
# HalfMassRad_DM: float64
# nodeIndex: float64
# PosInFile: float64
# FileNum: float64
# Image_ID: float64
# LookbackTime: float64
# UniverseAge: float64
